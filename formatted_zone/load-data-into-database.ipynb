# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
# Define the Postgres database connection
database_url = 'postgresql+psycopg2://bdm:test123@localhost/bdm_joint'  # Replace with your database connection details


#'postgresql://abdalrhman:abdalrhman@localhost/abdalrhman'

# Define the path to the folder contains the CSV files
csv_folder_path = './'  # Replace with the actual path to your CSV file

# Create a connection to the Postgres database
engine = create_engine(database_url)

# %%
# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_folder_path + 'users.csv')

# Write the DataFrame to the Postgres database
data.to_sql('users', engine, if_exists='replace', index=False)

# %%
data
# Out:
#     user_id  gender nationality         dob is_traveller       city
# 0         0  Female       Spain   1963/9/25            t      Palma
# 1         1    Male       Spain  1996/12/12            t      Palma
# 2         2  Female       Spain   1976/7/13            t  Barcelona
# 3         3    Male       Spain    1981/3/4            t     Madrid
# 4         4  Female       Spain   1968/3/16            t     Madrid
# 5         5    Male       Spain   1993/6/26            t      Palma
# 6         6  Female       Spain   1966/8/14            t      Palma
# 7         7    Male       Spain   2003/9/18            t      Palma
# 8         8  Female       Spain   1997/8/20            t     Malaga
# 9         9    Male       Spain   1967/12/9            t  Barcelona
# 10       10  Female       Spain   1986/9/13            t     Madrid
# 11       11    Male       Spain    2003/6/8            t      Palma
# 12       12  Female       Spain    1975/7/2            t     Madrid
# 13       13    Male       Spain   1999/7/28            t     Malaga
# 14       14  Female       Spain    1972/4/5            t      Palma
# 15       15    Male       Spain   1981/5/23            t     Malaga
# 16       16  Female       Spain   1990/3/27            t     Malaga
# 17       17    Male       Spain   1964/4/18            t  Barcelona
# 18       18  Female       Spain   1996/1/15            t  Barcelona
# 19       19    Male       Spain   1964/6/14            t     Malaga
# 20       20  Female       Spain   1967/6/21            f     Madrid
# 21       21    Male       Spain   2005/9/11            f      Palma
# 22       22  Female       Spain   1992/6/27            f     Madrid
# 23       23    Male       Spain    1974/9/5            f      Palma
# 24       24  Female       Spain   1967/9/20            f     Madrid
# 25       25  Female       Spain    1988/1/6            f     Malaga
# 26       26    Male       Spain    2005/5/8            f      Palma
# 27       27  Female       Spain   1978/10/9            f  Barcelona
# 28       28    Male       Spain   1968/1/26            f  Barcelona
# 29       29  Female       Spain  2004/10/15            f     Madrid
# 30       30    Male       Spain   1977/2/14            f     Madrid
# 31       31  Female       Spain    1990/3/8            f     Malaga
# 32       32    Male       Spain   1988/9/24            f     Malaga
# 33       33  Female       Spain   1967/3/18            f     Madrid
# 34       34    Male       Spain   1995/8/23            f     Malaga
# 35       35  Female       Spain    1981/5/7            f  Barcelona
# 36       36    Male       Spain   1968/4/22            f  Barcelona
# 37       37  Female       Spain  1975/12/20            f  Barcelona
# 38       38    Male       Spain   1966/5/25            f     Malaga
# 39       39  Female       Spain   1971/11/4            f  Barcelona

# %%
# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_folder_path + 'city_distances.csv')

# Write the DataFrame to the Postgres database
data.to_sql('city_distances', engine, if_exists='replace', index=False)

# %%
data
# Out:
#    country1    name1 country2      name2  distance_km currency  lpg_price  \
# 0     Spain   Madrid    Spain    Alacant   360.127617     euro  28.032334
# 1     Spain   Madrid    Spain     Malaga   414.957672     euro  32.300305
# 2     Spain   Madrid    Spain    Sevilla   390.504192     euro  30.396846
# 3     Spain   Madrid    Spain      Palma   550.581189     euro  42.857240
# 4     Spain   Madrid    Spain  Barcelona   506.922016     euro  39.458810
# 5     Spain  Alacant    Spain     Malaga   391.476854     euro  30.472558
# 6     Spain  Alacant    Spain    Sevilla   495.959990     euro  38.605526
# 7     Spain  Alacant    Spain      Palma   304.141921     euro  23.674407
# 8     Spain  Alacant    Spain  Barcelona   407.252380     euro  31.700525
# 9     Spain   Malaga    Spain    Sevilla   158.358120     euro  12.326596
# 10    Spain   Malaga    Spain      Palma   695.568426     euro  54.143046
# 11    Spain   Malaga    Spain  Barcelona   770.356791     euro  59.964573
# 12    Spain  Sevilla    Spain      Palma   791.886788     euro  61.640468
# 13    Spain  Sevilla    Spain  Barcelona   831.557005     euro  64.728397
# 14    Spain    Palma    Spain  Barcelona   205.306040     euro  15.981022
#
#     diesel_price  gasoline_price
# 0      27.729826       36.822689
# 1      31.951741       42.429007
# 2      30.068823       39.928663
# 3      42.394752       56.296376
# 4      39.032995       51.832269
# 5      30.143718       40.028117
# 6      38.188919       50.711413
# 7      23.418928       31.098207
# 8      31.358433       41.641149
# 9      12.193575       16.191959
# 10     53.558769       71.121176
# 11     59.317473       78.768212
# 12     60.975283       80.969632
# 13     64.029889       85.025872
# 14     15.808565       20.992337

# %%
# # Read the CSV file into a pandas DataFrame
# data = pd.read_csv(csv_folder_path + 'dhl_price.csv')

# # Write the DataFrame to the Postgres database
# data.to_sql('dhl_price', engine, if_exists='replace', index=False)

# %%
# # Read the CSV file into a pandas DataFrame
# data = pd.read_csv(csv_folder_path + 'dhl_zone.csv')

# # Write the DataFrame to the Postgres database
# data.to_sql('dhl_zone', engine, if_exists='replace', index=False)

# %%
# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_folder_path + 'flights.csv')

# Write the DataFrame to the Postgres database
data.to_sql('flights', engine, if_exists='replace', index=False)

# %%
data
# Out:
#       flightNumber departureAirportFsCode arrivalAirportFsCode  \
# 0             1007                    MAD                  BCN
# 1             1007                    MAD                  BCN
# 2             5005                    MAD                  BCN
# 3             3546                    MAD                  BCN
# 4             7703                    MAD                  BCN
# ...            ...                    ...                  ...
# 3930          3150                    AGP                  PMI
# 3931          5259                    AGP                  PMI
# 3932          5677                    AGP                  PMI
# 3933          3148                    AGP                  PMI
# 3934          5257                    AGP                  PMI
#
#             departureTime          arrivalTime  stops  departureTerminal  \
# 0     2023-04-23 18:25:00  2023-04-23 19:45:00      0                4.0
# 1     2023-04-23 18:25:00  2023-04-23 19:45:00      0                4.0
# 2     2023-04-23 18:25:00  2023-04-23 19:45:00      0                4.0
# 3     2023-04-23 18:25:00  2023-04-23 19:45:00      0                4.0
# 4     2023-04-23 15:10:00  2023-04-23 16:35:00      0                2.0
# ...                   ...                  ...    ...                ...
# 3930  2023-04-28 21:05:00  2023-04-28 22:35:00      0                NaN
# 3931  2023-04-28 21:05:00  2023-04-28 22:35:00      0                NaN
# 3932  2023-04-29 21:35:00  2023-04-29 23:05:00      0                NaN
# 3933  2023-04-29 13:35:00  2023-04-29 15:05:00      0                NaN
# 3934  2023-04-29 13:35:00  2023-04-29 15:05:00      0                NaN
#
#       arrivalTerminal
# 0                 1.0
# 1                 1.0
# 2                 1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 3930              NaN
# 3931              NaN
# 3932              NaN
# 3933              NaN
# 3934              NaN
#
# [3935 rows x 8 columns]

# %%
# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_folder_path + 'products.csv')

# Write the DataFrame to the Postgres database
data.to_sql('products', engine, if_exists='replace', index=False)

# %%
data
# Out:
#                            product_id  product_weight_g  product_length_cm  \
# 0    1e9e8ef04dbcff4541ed26657ea517e5               225                 16
# 1    6a2fb4dd53d2cdb88e0432f1284a004c               400                 27
# 2    0d009643171aee696f4733340bc2fdd0               422                 21
# 3    b1eae565a61935e0011ee7682fef9dc9               267                 17
# 4    8da90b37f0fb171b4877c124f965b1f6               377                 18
# ..                                ...               ...                ...
# 120  91e6a181c1ebe734ab459822cee89763               850                 48
# 121  af8215adef2df1e9e66642f159e81e55               400                 20
# 122  35255921c732e0e9319097469d856cd5               400                 18
# 123  25a675783383c8e0aa707b7e9063c925               253                 18
# 124  ba3fea9ec13fb882dda6c9e4295d9130               667                 20
#
#      product_height_cm  product_width_cm product_category_name_english  \
# 0                   10                14                     perfumery
# 1                    5                20                     perfumery
# 2                   16                18                     perfumery
# 3                   13                17                     perfumery
# 4                   13                15                     perfumery
# ..                 ...               ...                           ...
# 120                 16                25                 watches_gifts
# 121                 11                19                 watches_gifts
# 122                 11                15                 watches_gifts
# 123                 11                13                 watches_gifts
# 124                 17                18                 watches_gifts
#
#                           product_name
# 0       Acqua di Gio by Giorgio Armani
# 1              Alien by Thierry Mugler
# 2    Black Opium by Yves Saint Laurent
# 3             Bleu de Chanel by Chanel
# 4            Bright Crystal by Versace
# ..                                 ...
# 120                     Tissot T-Touch
# 121                      Casio G-Shock
# 122                    Timex Weekender
# 123                       Fossil Grant
# 124                Michael Kors Runway
#
# [125 rows x 7 columns]

# %%
# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_folder_path + 'requests.csv')

# Write the DataFrame to the Postgres database
data.to_sql('requests', engine, if_exists='replace', index=False)

# %%
data
# Out:
#      requestId  initializationUserId  collectionUserId  travellerId  \
# 0            0                    24                26          0.0
# 1            1                    28                33         15.0
# 2            2                    27                23         15.0
# 3            3                    22                38          3.0
# 4            4                    29                37         19.0
# ..         ...                   ...               ...          ...
# 215        215                    24                31          NaN
# 216        216                    21                38          NaN
# 217        217                    23                38          NaN
# 218        218                    39                24          NaN
# 219        219                    38                20          NaN
#
#                             productId        dateToDeliver  \
# 0    d68bd4dedccc5545b1ff6629de8fb021  2023-08-07 08:16:00
# 1    b864b103180d5a6a3f830e67f93e8735  2023-09-16 22:08:00
# 2    be1be330cf34043d1c40d6114cbd11b5  2023-08-22 04:37:00
# 3    062e425d963f3eac04709162c3ce6782  2023-06-24 16:55:00
# 4    dbb399a8be7395d5b136d49fcdce13df  2023-09-09 11:56:00
# ..                                ...                  ...
# 215  c20fbbd4ccf2f7da70e150689a6a905f  2023-04-26 09:51:00
# 216  dbb399a8be7395d5b136d49fcdce13df  2023-04-18 12:16:00
# 217  483df9288035696f34225a7047591d13  2023-04-22 03:02:00
# 218  3488d2ce36e718097c1509444289ef7f  2023-04-26 17:32:00
# 219  69e3a7b303638194dc5edd5e6abff8ff  2023-04-29 14:23:00
#
#            dateDelivered          requestDate  pickUpAddress  \
# 0    2023-08-03 08:55:00  2023-07-28 08:16:00             24
# 1    2023-09-10 21:55:00  2023-09-06 22:08:00             28
# 2    2023-08-14 10:21:00  2023-08-11 04:37:00             27
# 3    2023-06-24 15:34:00  2023-06-18 16:55:00             22
# 4    2023-09-01 17:27:00  2023-08-29 11:56:00             29
# ..                   ...                  ...            ...
# 215                  NaN  2023-04-16 09:51:00             24
# 216                  NaN  2023-04-11 12:16:00             21
# 217                  NaN  2023-04-11 03:02:00             23
# 218                  NaN  2023-04-15 17:32:00             39
# 219                  NaN  2023-04-16 14:23:00             38
#
#      collectionAddress  deliveryFee Satisfactory  dhl_fee
# 0                   26     4.587871            t    17.05
# 1                   33     2.739487            t    16.78
# 2                   23     2.321269            f    17.05
# 3                   38     3.061754            t    16.78
# 4                   37     3.886117            t    16.78
# ..                 ...          ...          ...      ...
# 215                 31          NaN          NaN    16.78
# 216                 38          NaN          NaN    17.05
# 217                 38          NaN          NaN    17.05
# 218                 24          NaN          NaN    16.78
# 219                 20          NaN          NaN    16.78
#
# [220 rows x 13 columns]

# %%
# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_folder_path + 'travels.csv')

# Write the DataFrame to the Postgres database
data.to_sql('travels', engine, if_exists='replace', index=False)

# %%
data
# Out:
#     userId departureAirportFsCode arrivalAirportFsCode    departureTime  \
# 0        0                 Madrid            Barcelona  2023/4/22 20:00
# 1        0              Barcelona               Madrid  2023/4/25 12:40
# 2        1                 Madrid            Barcelona  2023/4/19 15:10
# 3        1              Barcelona               Madrid  2023/4/22 18:05
# 4        2                 Madrid            Barcelona  2023/4/19 20:00
# 5        2              Barcelona               Madrid  2023/4/23 18:05
# 6        3                  Palma               Malaga   2023/4/21 6:45
# 7        3                 Malaga                Palma  2023/4/24 20:40
# 8        4                 Madrid            Barcelona  2023/4/19 16:30
# 9        4              Barcelona               Madrid  2023/4/23 11:35
# 10       5                 Madrid               Malaga  2023/4/21 15:00
# 11       5                 Malaga               Madrid   2023/4/25 9:20
# 12       6              Barcelona                Palma  2023/4/22 18:45
# 13       6                  Palma            Barcelona   2023/4/25 8:00
# 14       7              Barcelona               Malaga   2023/4/21 6:50
# 15       7                 Malaga            Barcelona  2023/4/24 15:10
# 16       8                 Madrid               Malaga  2023/4/21 10:35
# 17       8                 Malaga               Madrid   2023/4/24 8:35
# 18       9              Barcelona                Palma  2023/4/20 16:05
# 19       9                  Palma            Barcelona   2023/4/24 7:05
# 20      10                  Palma               Malaga  2023/4/22 15:40
# 21      10                 Malaga                Palma  2023/4/25 16:20
# 22      11              Barcelona                Palma  2023/4/21 13:40
# 23      11                  Palma            Barcelona  2023/4/24 21:10
# 24      12                 Madrid                Palma  2023/4/22 19:35
# 25      12                  Palma               Madrid  2023/4/25 10:40
# 26      13              Barcelona               Malaga  2023/4/20 15:50
# 27      13                 Malaga            Barcelona   2023/4/24 6:45
# 28      14                  Palma               Malaga  2023/4/19 19:50
# 29      14                 Malaga                Palma  2023/4/22 13:35
# 30      15                 Madrid               Malaga   2023/4/20 7:30
# 31      15                 Malaga               Madrid   2023/4/24 8:35
# 32      16              Barcelona                Palma  2023/4/20 20:40
# 33      16                  Palma            Barcelona  2023/4/24 21:10
# 34      17                 Madrid                Palma  2023/4/22 17:05
# 35      17                  Palma               Madrid   2023/4/25 8:00
# 36      18                 Madrid            Barcelona  2023/4/21 20:00
# 37      18              Barcelona               Madrid  2023/4/25 10:05
# 38      19              Barcelona               Malaga   2023/4/19 6:50
# 39      19                 Malaga            Barcelona  2023/4/22 23:10
#
#         arrivalTime  extraLuggage
# 0   2023/4/22 21:20             4
# 1   2023/4/25 14:05             7
# 2   2023/4/19 16:35             4
# 3   2023/4/22 19:30             3
# 4   2023/4/19 21:20             7
# 5   2023/4/23 19:30             4
# 6    2023/4/21 8:20             5
# 7   2023/4/24 22:05             3
# 8   2023/4/19 17:50             6
# 9   2023/4/23 13:05             4
# 10  2023/4/21 16:15             4
# 11  2023/4/25 10:40             4
# 12  2023/4/22 19:30             4
# 13   2023/4/25 8:55             2
# 14   2023/4/21 8:30             3
# 15  2023/4/24 16:50             3
# 16  2023/4/21 11:50             5
# 17   2023/4/24 9:45             2
# 18  2023/4/20 17:00             4
# 19   2023/4/24 7:55             6
# 20  2023/4/22 17:15             6
# 21  2023/4/25 17:50             2
# 22  2023/4/21 14:40             7
# 23  2023/4/24 22:05             4
# 24  2023/4/22 20:55             3
# 25  2023/4/25 12:05             3
# 26  2023/4/20 17:30             3
# 27   2023/4/24 8:25             5
# 28  2023/4/19 21:25             2
# 29  2023/4/22 15:05             5
# 30   2023/4/20 8:45             5
# 31   2023/4/24 9:45             2
# 32  2023/4/20 21:30             3
# 33  2023/4/24 22:05             8
# 34  2023/4/22 18:25             3
# 35   2023/4/25 9:25             2
# 36  2023/4/21 21:20             7
# 37  2023/4/25 11:30             1
# 38   2023/4/19 8:30             6
# 39   2023/4/23 0:45             4

# %%
# # Read the CSV file into a pandas DataFrame
# data = pd.read_csv(csv_folder_path + 'new_requests.csv')

# # Write the DataFrame to the Postgres database
# data.to_sql('new_requests', engine, if_exists='replace', index=False)

# %%
# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_folder_path + 'addresses.csv')

# Write the DataFrame to the Postgres database
data.to_sql('travels', engine, if_exists='replace', index=False)

# %%
data
# Out:
#     user_id  gender nationality         dob is_traveller       city
# 0         0  Female       Spain   1963/9/25            t      Palma
# 1         1    Male       Spain  1996/12/12            t      Palma
# 2         2  Female       Spain   1976/7/13            t  Barcelona
# 3         3    Male       Spain    1981/3/4            t     Madrid
# 4         4  Female       Spain   1968/3/16            t     Madrid
# 5         5    Male       Spain   1993/6/26            t      Palma
# 6         6  Female       Spain   1966/8/14            t      Palma
# 7         7    Male       Spain   2003/9/18            t      Palma
# 8         8  Female       Spain   1997/8/20            t     Malaga
# 9         9    Male       Spain   1967/12/9            t  Barcelona
# 10       10  Female       Spain   1986/9/13            t     Madrid
# 11       11    Male       Spain    2003/6/8            t      Palma
# 12       12  Female       Spain    1975/7/2            t     Madrid
# 13       13    Male       Spain   1999/7/28            t     Malaga
# 14       14  Female       Spain    1972/4/5            t      Palma
# 15       15    Male       Spain   1981/5/23            t     Malaga
# 16       16  Female       Spain   1990/3/27            t     Malaga
# 17       17    Male       Spain   1964/4/18            t  Barcelona
# 18       18  Female       Spain   1996/1/15            t  Barcelona
# 19       19    Male       Spain   1964/6/14            t     Malaga
# 20       20  Female       Spain   1967/6/21            f     Madrid
# 21       21    Male       Spain   2005/9/11            f      Palma
# 22       22  Female       Spain   1992/6/27            f     Madrid
# 23       23    Male       Spain    1974/9/5            f      Palma
# 24       24  Female       Spain   1967/9/20            f     Madrid
# 25       25  Female       Spain    1988/1/6            f     Malaga
# 26       26    Male       Spain    2005/5/8            f      Palma
# 27       27  Female       Spain   1978/10/9            f  Barcelona
# 28       28    Male       Spain   1968/1/26            f  Barcelona
# 29       29  Female       Spain  2004/10/15            f     Madrid
# 30       30    Male       Spain   1977/2/14            f     Madrid
# 31       31  Female       Spain    1990/3/8            f     Malaga
# 32       32    Male       Spain   1988/9/24            f     Malaga
# 33       33  Female       Spain   1967/3/18            f     Madrid
# 34       34    Male       Spain   1995/8/23            f     Malaga
# 35       35  Female       Spain    1981/5/7            f  Barcelona
# 36       36    Male       Spain   1968/4/22            f  Barcelona
# 37       37  Female       Spain  1975/12/20            f  Barcelona
# 38       38    Male       Spain   1966/5/25            f     Malaga
# 39       39  Female       Spain   1971/11/4            f  Barcelona
